# %% [markdown]
# ### Install

# %%
x =5
x
# Out:
# 5

# %%
# !pip install -r requirements.txt
# Out:
# Collecting torch (from -r requirements.txt (line 1))
#   Using cached torch-2.5.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting torchvision (from -r requirements.txt (line 2))
#   Using cached torchvision-0.20.1-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# Collecting transformers (from -r requirements.txt (line 3))
#   Using cached transformers-4.47.1-py3-none-any.whl.metadata (44 kB)
# Collecting pytorch-transformers (from -r requirements.txt (line 4))
#   Using cached pytorch_transformers-1.2.0-py3-none-any.whl.metadata (21 kB)
# Collecting numpy (from -r requirements.txt (line 5))
#   Using cached numpy-2.2.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting opencv-python (from -r requirements.txt (line 6))
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting Pillow (from -r requirements.txt (line 7))
#   Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting tqdm (from -r requirements.txt (line 8))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting anytree (from -r requirements.txt (line 9))
#   Using cached anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting yacs (from -r requirements.txt (line 10))
#   Using cached yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Collecting pycocotools (from -r requirements.txt (line 11))
#   Using cached pycocotools-2.0.8-cp312-cp312-win_amd64.whl.metadata (1.1 kB)
# Collecting timm (from -r requirements.txt (line 12))
#   Using cached timm-1.0.12-py3-none-any.whl.metadata (51 kB)
# Collecting einops (from -r requirements.txt (line 13))
#   Using cached einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting PyYAML (from -r requirements.txt (line 14))
#   Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting cython (from -r requirements.txt (line 15))
#   Using cached Cython-3.0.11-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Collecting ninja (from -r requirements.txt (line 16))
#   Using cached ninja-1.11.1.3-py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting clint (from -r requirements.txt (line 17))
#   Using cached clint-0.5.1-py3-none-any.whl
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: 'C:\\users\\engma\\appdata\\local\\pip\\cache\\wheels\\bc\\e0\\13\\9d21ea8729ace98b0782d861d53f4b33f535b5ce50d997d9c9\\clint-0.5.1-py3-none-any.whl'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install git+https://github.com/Mahmood-Anaam/vinvl.git
# Out:
# Collecting git+https://github.com/Mahmood-Anaam/vinvl.git
#   Cloning https://github.com/Mahmood-Anaam/vinvl.git to c:\users\engma\appdata\local\temp\pip-req-build-lzyqstqo
#   Running command git clone --filter=blob:none --quiet https://github.com/Mahmood-Anaam/vinvl.git 'C:\Users\engma\AppData\Local\Temp\pip-req-build-lzyqstqo'
#   error: RPC failed; curl 92 HTTP/2 stream 3 was not closed cleanly: CANCEL (err 8)
#   error: 919 bytes of body are still expected
#   fetch-pack: unexpected disconnect while reading sideband packet
#   fatal: early EOF
#   fatal: fetch-pack: invalid index-pack output
#   fatal: could not fetch c79f51434f8dc6c1e95f0895cf81a6f582bc472d from promisor remote
#   warning: Clone succeeded, but checkout failed.
#   You can inspect what was checked out with 'git status'
#   and retry with 'git restore --source=HEAD :/'
#
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/Mahmood-Anaam/vinvl.git 'C:\Users\engma\AppData\Local\Temp\pip-req-build-lzyqstqo' did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/Mahmood-Anaam/vinvl.git 'C:\Users\engma\AppData\Local\Temp\pip-req-build-lzyqstqo' did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install git+https://github.com/Mahmood-Anaam/vinvl_bert.git

# %%
# !pip install  -e . --quiet
# Out:
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/Mahmood-Anaam/vinvl.git 'C:\Users\engma\AppData\Local\Temp\pip-install-v6rutb6a\vinvl_017586d89f35466b93ce38b9abf69a85' did not run successfully.
#   │ exit code: 128
#   ╰─> [10 lines of output]
#       error: RPC failed; curl 56 OpenSSL SSL_read: SSL_ERROR_SYSCALL, errno 0
#       error: 3491 bytes of body are still expected
#       fetch-pack: unexpected disconnect while reading sideband packet
#       fatal: early EOF
#       fatal: fetch-pack: invalid index-pack output
#       fatal: could not fetch c79f51434f8dc6c1e95f0895cf81a6f582bc472d from promisor remote
#       warning: Clone succeeded, but checkout failed.
#       You can inspect what was checked out with 'git status'
#       and retry with 'git restore --source=HEAD :/'
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/Mahmood-Anaam/vinvl.git 'C:\Users\engma\AppData\Local\Temp\pip-install-v6rutb6a\vinvl_017586d89f35466b93ce38b9abf69a85' did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# ### Import all libraries

# %%
import warnings
warnings.filterwarnings("ignore")

from PIL import Image
import requests
import torch
import numpy as np

# %%
# import aravqa
import violet
import vinvl
import vinvl_bert

# %% [markdown]
# ### Test
