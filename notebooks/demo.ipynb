# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmood-Anaam/arabic-visual-question-answering/blob/main/notebooks/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install

# %%
#!pip install git+https://github.com/Mahmood-Anaam/Violet.git --quiet

# %%
# !pip install git+https://github.com/Mahmood-Anaam/VinVL.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.6/473.6 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.7 MB/s eta 0:00:00
#   Building wheel for vinvl (setup.py) ... done
#   Building wheel for clint (setup.py) ... done
#   Building wheel for args (setup.py) ... done
#   Building wheel for typing (setup.py) ... done

# %%
# !pip install git+https://github.com/Mahmood-Anaam/vinvl_bert.git --quiet

# %%
# !pip install git+https://github.com/Mahmood-Anaam/VinVL.git --quiet
# !pip install git+https://github.com/Mahmood-Anaam/arabic-visual-question-answering.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.6/473.6 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 3.8 MB/s eta 0:00:00
#   Building wheel for vinvl (setup.py) ... done
#   Building wheel for clint (setup.py) ... done
#   Building wheel for args (setup.py) ... done
#   Building wheel for typing (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 85.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 5.0 MB/s eta 0:00:00
#   Building wheel for aravqa (setup.py) ... done
#   Building wheel for vinvl_bert (setup.py) ... done
#   Building wheel for Violet (setup.py) ... done

# %% [markdown]
# ### Import all libraries

# %%
import warnings
warnings.filterwarnings("ignore")

from PIL import Image
import requests
import torch
import numpy as np

# %%
import aravqa
import violet
import vinvl
import vinvl_bert

# %% [markdown]
# ### Test

# %%
import vinvl

from vinvl.scene_graph_benchmark.wrappers import VinVLVisualBackbone
v = VinVLVisualBackbone()

# %%
from vinvl_bert.feature_extractors.vinvl import VinVLFeatureExtractor

# %%
feature_extractor = VinVLFeatureExtractor()
# Out:
# Downloading vinvl_vg_x152c4.pth: 579565it [00:09, 59661.94it/s]
# Downloading VG-SGG-dicts-vgoi6-clipped.json: 107it [00:00, 4900.80it/s]
