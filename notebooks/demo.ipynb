# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmood-Anaam/arabic-visual-question-answering/blob/main/notebooks/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install

# %%
# !pip install git+https://github.com/Mahmood-Anaam/arabic-visual-question-answering.git -q

# %%
# !git clone https://github.com/Mahmood-Anaam/arabic-visual-question-answering.git
# %cd arabic-visual-question-answering
# !pip install -e . -q
# Out:
# Cloning into 'arabic-visual-question-answering'...
# remote: Enumerating objects: 515, done.
# remote: Counting objects: 100% (515/515), done.
# remote: Compressing objects: 100% (384/384), done.
# remote: Total 515 (delta 126), reused 503 (delta 116), pack-reused 0 (from 0)
# Receiving objects: 100% (515/515), 12.05 MiB | 29.11 MiB/s, done.
# Resolving deltas: 100% (126/126), done.
# /content/arabic-visual-question-answering
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.6/473.6 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 52.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 6.7 MB/s eta 0:00:00
#   Building wheel for clint (setup.py) ... done
#   Building wheel for args (setup.py) ... done
#   Building wheel for typing (setup.py) ... done

# %% [markdown]
# ### Import all libraries

# %%
import warnings
warnings.filterwarnings("ignore")

from PIL import Image
import requests
import torch
import numpy as np

# %%
import captions
import llms
